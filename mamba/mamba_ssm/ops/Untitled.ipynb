# %%
import causal_conv1d_cuda
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import causal_conv1d_cuda
#
# ImportError: libc10.so: cannot open shared object file: No such file or directory
